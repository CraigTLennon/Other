# %% [markdown]
# Notes from the book SciPy and Numpy

# %% [markdown]
# Chapter 2:

# %%
import numpy as np
#numpy array, like C/java array stores one type.  Create array with 100 elements
arr=np.arange(100) #from 1 to number
#convert to list
larr=arr.tolist() #now a python list
#create 3-d array with all zeros
arr3=np.zeros((3,3,3))
#other ways to create:  from list, all zeros, range, linear steps,
#logspace steps.  default is float byt can do int string, etc.
arr=np.array([1,2,3])
arr=np.zeros(5)
arr=np.zeros(5).astype(int)
arr=np.zeros(5).astype(np.character)
arr=np.zeros(5).astype(np.uint8)
arr=np.linspace(0,1,100)
arr=np.logspace(0,1,100,base=2)
mat=np.zeros((5,5))
cube=np.zeros((5,5,5))
#reshaping arrays
arr1d=np.arange(1000)
arr3d=arr1d.reshape((10,10,10))
arr4d=np.zeros((10,10,10,10))
arr2d=arr4d.reshape((100,100))
arr1d=arr4d.ravel()
arr1d.shape
# Out:
# (10000,)

# %% [markdown]
# Record arrays (numpy.recarray) below (note i4 is int 2^4, float

# %%
recarr=np.zeros((2,),dtype=('i4,f4,a10'))
recarr
# Out:
# array([(0, 0.0, b''), (0, 0.0, b'')],
#       dtype=[('f0', '<i4'), ('f1', '<f4'), ('f2', 'S10')])
