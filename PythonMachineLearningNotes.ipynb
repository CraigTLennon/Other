# %%
import sklearn as sk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib import rcParams
#set plot figure size
rcParams["figure.figsize"]=10,5
# %matplotlib inline

# %% [markdown]
# Implementing a perceptr
# on in python, b/c why not?

# %%
class Perceptron(object):
    """
    Parameters
    eta float learning rate between 0.0 and 1.0
    n_iter int the number of passes over the training set
    Attributes
    w_ 1 dim array which holds the weights after fitting
    errors_ listnumber of misclassifications in each epoch
    
    """
